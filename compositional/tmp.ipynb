# %%
import xarray as xr 
import matplotlib.pylab as plt

# %%
out_dir = ("/data/home/hamiddashti/nasa_above/outputs/")
lst_mean = xr.open_dataset(out_dir +
                           "lst_processed/albers_proj_lst_mean_Annual.nc",
                           decode_coords="all")
lst_mean = lst_mean["lst_mean_Annual"]
lst_mean
# Out:
# <xarray.DataArray 'lst_mean_Annual' (year: 13, y: 4343, x: 4172)>
# [235546948 values with dtype=float64]
# Coordinates:
#   * x            (x) float64 -3.382e+06 -3.381e+06 ... 4.817e+05 4.826e+05
#   * y            (y) float64 5.361e+06 5.36e+06 ... 1.338e+06 1.337e+06
#   * year         (year) int64 2002 2003 2004 2005 2006 ... 2011 2012 2013 2014
#     spatial_ref  int64 ...

# %%
plt.close()
lst_mean.isel(year=1).plot()
